# %% [markdown]
# # Machine Learning : Linear Regression

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model
# %matplotlib inline

# %%
df=pd.read_csv("homeprices.csv")
df.area
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df[['price']])
# Out:
# LinearRegression()

# %%
reg.predict(df[['area']])
# Out:
# array([[533664.38356164],
#        [587979.45205479],
#        [615136.98630137],
#        [669452.05479452],
#        [723767.12328767]])

# %%
# %matplotlib inline 
plt.scatter(df.area, df.price, color='red',marker='*')
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg.coef_
# Out:
# array([[135.78767123]])

# %%
reg.intercept_
# Out:
# array([180616.43835616])

# %%
135.78767123*3000+180616.43835616
# Out:
# 587979.45204616

# %%
d=pd.read_csv("areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
d.head(4)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d.to_csv('prediction.csv',index=False)
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %% [markdown]
# # Linear regression / Multivarite Regression

# %%
df=pd.read_csv("homeprices2.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.fillna(df['bedrooms'].mean(),inplace=True)

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.2   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg.fit(df[['area','bedrooms','age']],df[['price']])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[  116.66950551, 18756.28806982, -3675.75111708]])

# %%
reg.intercept_
# Out:
# array([231586.00639409])

# %%
reg.predict([[3000,3,40]])
# Out:
# C:\Users\Kousimon\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[490833.34243748]])

# %%
reg.predict([[3000,3,10]])
# Out:
# C:\Users\Kousimon\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[601105.87594985]])

# %%
116.66950551*3000+18756.28806982*3+-3675.75111708*40+231586.00639409
# Out:
# 490833.34245034994

# %%
reg.predict([[2400,3,5]])
# Out:
# C:\Users\Kousimon\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[549482.92823183]])

# %%
# EXCERCISE

# %%
from word2number import w2n

# %%
dt=pd.read_csv("hiring.csv")
dt
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
dt.experience=dt.experience.fillna("zero")
dt
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
dt.experience=dt.experience.apply(w2n.word_to_num)

# %%
dt.fillna(dt[['test_score(out of 10)']].mean(),inplace=True)

# %%
dt
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0               8.000000                           9      50000
# 1           0               8.000000                           6      45000
# 2           5               6.000000                           7      60000
# 3           2              10.000000                          10      65000
# 4           7               9.000000                           6      70000
# 5           3               7.000000                          10      62000
# 6          10               7.857143                           7      72000
# 7          11               7.000000                           8      80000

# %%
reg.fit(dt[['experience','test_score(out of 10)','interview_score(out of 10)']],dt[['salary($)']])
# Out:
# LinearRegression()

# %%
reg.predict([[4,9,7]])
# Out:
# C:\Users\Kousimon\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[61143.13595984]])

# %%
reg.coef_
# Out:
# array([[2827.63404314, 1912.93803053, 2196.9753141 ]])

# %%
reg.intercept_
# Out:
# array([17237.33031373])

# %%
2827.63404314*+1912.93803053*9+2196.9753141*7+17237.33031373
# Out:
# 48714414.435406744
